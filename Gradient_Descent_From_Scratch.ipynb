# %% [markdown]
# <a href="https://colab.research.google.com/github/chonorat/Data-Mining-Projects/blob/master/Gradient_Descent_From_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import random
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

####################################
##############Dot Product
#################################
def dot_prod(W_Vector,F_Vector):
    dp=0
    for i in range(0,len(W_Vector)):
        dp=dp+(W_Vector[i]*(F_Vector[i]))
    return(dp)



####################
###Read Data############
######################
datafile='/content/ionosphere.data'
f=open(datafile)
data=[]
i=0
l=f.readline()
while(l!=''):
	a=l.split()
	l2=[]
	for j in range(0,len(a),1):
		l2.append(float(a[j]))
	data.append(l2)
	l=f.readline()


####
###Add column of ones to data
######
rows=len(data)	
for i in range(0,rows):
	data[i].append(1)
f.close()
cols=len(data[0])



#################
##################Read Labels
###################
labelfile='/content/ionosphere_trailabels.data'
f=open(labelfile)
trainlabels={}
n=[]
n.append(0)
n.append(0)
l=f.readline()
while(l !=''):
	a=l.split()
	if int(a[0])==1 or int(a[0])==0:
		trainlabels[int(a[1])]=int(a[0])
		n[int(a[0])]+=1
	l=f.readline()



########################
##Initiate Dellf
######################
dellf=[]
for j in range(0,cols,1):
        dellf.append(0)




##########
##set class labels
########
for i in range(0,rows-1):
	if(trainlabels.get(i)!=None and trainlabels[i]==0):
		trainlabels[i]=-1




####################
##########Initialize weights
#########################
w=[]
for k in range(0,cols,1):
        w.append(0)
for k in range(0,cols,1):
        w[k]=.02 * random.uniform(0,1) - .01


#####################################
#############Gradient Descent
#####################################
eta=.0001
error_diff=1
error=0
dotprod=0
while error_diff>.001:
	###Compute dellf####
	for i in range(0,rows):
		if(trainlabels.get(i)!=None):
			dotprod=dot_prod(w,data[i])
			for j in range(0,cols):
				dellf[j]=dellf[j]+((trainlabels[i]-dotprod)* data[i][j])
			

	#########
	####update
	####
	for j in range(0,cols):
		w[j]=w[j]+(eta*dellf[j])
		dellf[j]=0

	##########
	###compute error and error_difference
	########
	error_previous=error
	error=0
	for i in range(0,rows):
		if(trainlabels.get(i)!=None):
			error=error+(trainlabels[i]-dot_prod(w,data[i]))**2
	error_diff=((error_previous-error)**2)**.5
	#print("ERROR= ",error,"\n")


#####
#Calculate norm
####
normw=0
for i in range(0,cols-1):
	normw=normw+w[i]**2
normw=(normw)**.5
w[-1]=((w[-1]**2)**.5)
	

###########
####Predictions
##############
predictions=[]
for i in range(0,rows-1):
  if (trainlabels.get(i)==None):
    dp=dot_prod(w,data[i])
    if dp>0:
      print("Prediction ",i," = 1","\n")
      predictions.append(1)
    else:
      print("Prediction ",i," = 0","\n")
      predictions.append(-1)

#print("DISTANCE TO ORIGIN= ",w[-1]/normw,"\n")
print("WEIGHTS= ",w)
# Out:
# Prediction  3  = 0
#
# Prediction  5  = 1
#
# Prediction  21  = 1
#
# Prediction  31  = 1
#
# Prediction  39  = 0
#
# Prediction  56  = 0
#
# Prediction  63  = 0
#
# Prediction  88  = 0
#
# Prediction  89  = 0
#
# Prediction  99  = 0
#
# Prediction  103  = 0
#
# Prediction  106  = 1
#
# Prediction  137  = 1
#
# Prediction  151  = 0
#
# Prediction  156  = 1
#
# Prediction  167  = 0
#
# Prediction  177  = 0
#
# Prediction  181  = 0
#
# Prediction  190  = 1
#
# Prediction  210  = 1
#
# Prediction  216  = 0
#
# Prediction  221  = 0
#
# Prediction  234  = 0
#
# Prediction  239  = 0
#
# Prediction  251  = 0
#
# Prediction  254  = 0
#
# Prediction  262  = 0
#
# Prediction  276  = 0
#
# Prediction  288  = 0
#
# Prediction  292  = 0
#
# Prediction  298  = 0
#
# Prediction  300  = 0
#
# Prediction  307  = 0
#
# Prediction  337  = 0
#
# Prediction  343  = 0
#
# Prediction  349  = 0
#
# WEIGHTS=  [-0.5844786105490379, 0.003712771998623859, -0.42977739152501365, -0.27492990431092573, -0.42378399159145635, -0.2116077843536189, -0.2695542277919166, -0.30252311072430227, -0.27103738714762426, -0.05590313665362078, 0.1903940049038228, 0.05148823101759836, 0.23128468867272167, -0.0377986031299813, -0.10820634817390207, 0.052112790500061706, -0.17960882427459576, -0.09666868006983935, 0.21718999570286182, -0.12265145129421845, -0.06823686684984519, 0.4221638005978431, -0.18437935253061175, -0.14498199107288554, -0.12856132450938382, -0.20504762952506836, 0.42538732525267176, 0.0558122718391782, -0.1451913540198424, -0.12410805918544733, -0.18033931519423935, -0.007756836345206727, 0.02451557986348537, 0.26178064410871604, 0.9657955286804781]
